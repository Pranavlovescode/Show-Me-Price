# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranavlovescode/Mumbai-Price-predictor/blob/master/new_mumbai_price_prediction_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Mumbai.csv')
df.head()
print(df.shape)
# Out:
# (7719, 40)

# %%
df2 = df.copy()
df2.columns
# Out:
# Index(['Price', 'Area', 'Location', 'No. of Bedrooms', 'Resale',
#        'MaintenanceStaff', 'Gymnasium', 'SwimmingPool', 'LandscapedGardens',
#        'JoggingTrack', 'RainWaterHarvesting', 'IndoorGames', 'ShoppingMall',
#        'Intercom', 'SportsFacility', 'ATM', 'ClubHouse', 'School',
#        '24X7Security', 'PowerBackup', 'CarParking', 'StaffQuarter',
#        'Cafeteria', 'MultipurposeRoom', 'Hospital', 'WashingMachine',
#        'Gasconnection', 'AC', 'Wifi', 'Children'splayarea', 'LiftAvailable',
#        'BED', 'VaastuCompliant', 'Microwave', 'GolfCourse', 'TV',
#        'DiningTable', 'Sofa', 'Wardrobe', 'Refrigerator'],
#       dtype='object')

# %%
df2.describe()
# Out:
#               Price         Area  No. of Bedrooms       Resale  \
# count  6.925000e+03  6925.000000      6925.000000  6925.000000
# mean   1.525685e+07  1001.587870         1.921011     0.636534
# std    2.004537e+07   550.726546         0.857545     0.481032
# min    2.000000e+06   200.000000         1.000000     0.000000
# 25%    5.400000e+06   650.000000         1.000000     0.000000
# 50%    9.500000e+06   902.000000         2.000000     1.000000
# 75%    1.750000e+07  1180.000000         2.000000     1.000000
# max    4.200000e+08  8511.000000         7.000000     1.000000
#
#        MaintenanceStaff    Gymnasium  SwimmingPool  LandscapedGardens  \
# count       6925.000000  6925.000000   6925.000000        6925.000000
# mean           7.613141     7.596534      7.566643           7.569386
# std            3.104120     3.141905      3.208580           3.202530
# min            0.000000     0.000000      0.000000           0.000000
# ...

# %%
sns.boxplot(df2['Area'])
plt.show()

# %%
sns.boxplot(df2['No. of Bedrooms'])
# Out:
# <Axes: >

# %% [markdown]
# **Handling the Outliers**

# %%
sns.distplot(df2.Price,bins=100)
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_64940\2016801548.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2.Price,bins=100)
# C:\Users\prana\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Price', ylabel='Density'>

# %%
features = ['Area','No. of Bedrooms']
for feature in features:
    percentile75 = df2[feature].quantile(0.75)
    percentile25 = df2[feature].quantile(0.25)
    IQR = percentile75 - percentile25
    upper_limit = percentile75 + (1.5*IQR)
    lower_limit = percentile25 - (1.5*IQR)
    df2.loc[df2[feature]<=lower_limit,feature] = lower_limit # capping the outliers
    df2.loc[df2[feature]>=upper_limit,feature] = upper_limit

# %%
sns.boxplot(df2.Area)
# Out:
# <Axes: >

# %% [markdown]
#  Removed all the outliers from Area column

# %%
sns.boxplot(df2['No. of Bedrooms'])
# Out:
# <Axes: >

# %% [markdown]
# Removed all the outliers from No. of Bedrooms column

# %%
df2 = df2.drop_duplicates()
df2.shape
# Out:
# (6922, 40)

# %%
df3 = pd.get_dummies(df2).astype(int)
df3.head()
df3.columns
# Out:
# Index(['Price', 'Area', 'No. of Bedrooms', 'Resale', 'MaintenanceStaff',
#        'Gymnasium', 'SwimmingPool', 'LandscapedGardens', 'JoggingTrack',
#        'RainWaterHarvesting',
#        ...
#        'Location_royal palms goregaon east', 'Location_sec 50 new',
#        'Location_taloja panchanand', 'Location_thakur village kandivali east',
#        'Location_ulhasnagar 4', 'Location_vasant vihar thane west',
#        'Location_vile parle west', 'Location_vrindavan society',
#        'Location_worli sea Fase', 'Location_worli sea face'],
#       dtype='object', length=452)

# %%
correlation = df3.corr()

# %%
plt.figure(figsize=(35,35))
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >
